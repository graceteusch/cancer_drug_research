# %%
# group drugs according to their type/target
import pandas as pd

#read in supplementary table
drugInfo = pd.read_csv("Drug_Info_Supp_Table.csv")
drugInfo["Drug"] = drugInfo["Drug"].str.strip()
print(drugInfo["Drug"])


#group by drug type and turn into dictionary
drugTypes = drugInfo.groupby("Type")["Drug"].apply(list).to_dict()

# #print dictionary
# for type, drugs in drugTypes.items():
#     print(f"{type}: {drugs}")
# Out:
# 0                         Entinostat
# 1                       Mocetinostat
# 2                         Romidepsin
# 3                       Tacedinaline
# 4                       Tucidinostat
#                    ...
# 139                           TMP195
# 140                           TMP269
# 141    NFAT activation inhibitor III
# 142                    Cyclosporin A
# 143                           LMK235
# Name: Drug, Length: 144, dtype: object

# %%
# loop through the dictionary
for type, drugNames in drugTypes.items():
    # for each key (drug type), go through each of the drugs
    for drug in drugNames:
        # make a string with the drug name + _ALL.txt (or whatever the format is)
        fileName = f"{drug}_ALL.txt"
        # use ftp to download that file from massive (is this possible?? or only thru command line?)
        
    # start with just 1 drug type and try to combine them all (see code below)

# %%
from ftplib import FTP

ftp = FTP("massive-ftp.ucsd.edu")
ftp.login()
    
ftp.cwd('/v06/MSV000093659/other/Dose response data - Jurkat proteome/ACY738/TXTs_Classified')
    # only want Dose response data - Jurkat proteome 
    # maybe double check this w/ the paper but we're pretty sure!
print("curr diectory: ")
ftp.retrlines('LIST')

fileName = 'ACY738_ALL.txt' # could also turn this into filePath and put the whole path in. would prob be better for getting all drugs instead of changing directories

# write the file in binary mode
with open(fileName, "wb") as file:
    # download the file "RETR fileName"
    ftp.retrbinary(f"RETR {fileName}", file.write)
ftp.quit()


with open(fileName, "r") as dataFile:
    one = dataFile.readline()
    print(one)
    two = dataFile.readline()
    print(two)
# Out:
# curr diectory:
# -rw-rw-r--    1 1200     1200      3859444 Aug 16  2023 ACY738_ALL.txt
# -rw-rw-r--    1 1200     1200       719933 Aug 16  2023 ACY738_down, low confidence.txt
# -rw-rw-r--    1 1200     1200       123804 Aug 16  2023 ACY738_down.txt
# -rw-rw-r--    1 1200     1200      1923069 Aug 16  2023 ACY738_non-regulated.txt
# -rw-rw-r--    1 1200     1200       153580 Aug 16  2023 ACY738_up, low confidence.txt
# -rw-rw-r--    1 1200     1200        16422 Aug 16  2023 ACY738_up.txt
# .pred_class	identifier	drug	gene	slope	bottom	top	inflection	IC50	stdIC50	down	r2	rse	bic	aic	AUC	Normalized_Intensity_0	Normalized_Intensity_1	Normalized_Intensity_10	Normalized_Intensity_100	Normalized_Intensity_1000	Normalized_Intensity_10000	Unique_Peptides_0	Unique_Peptides_1	Unique_Peptides_10	Unique_Peptides_100	Unique_Peptides_1000	Unique_Peptides_10000	Description	Mean_Intensity	Gene names	DMSO_percentile	MAD	beginningOfCurve	endOfCurve	linearSlope	R2_Bins
#
# ...

# %%
# Testing different stuff out 


from ftplib import FTP

ftp = FTP("massive-ftp.ucsd.edu")
ftp.login()
    
ftp.cwd('/v06/MSV000093659/other/Dose response data - Jurkat proteome')
    # only want Dose response data - Jurkat proteome 
    # maybe double check this w/ the paper but we're pretty sure!


ftp.cwd("ACY738/TXTs_Classified")
print("curr diectory: ")
ftp.retrlines('LIST')

fileName = 'ACY738_ALL.txt' # could also turn this into filePath and put the whole path in. would prob be better for getting all drugs instead of changing directories

# write the file in binary mode
with open(fileName, "wb") as file:
    # download the file "RETR fileName"
    ftp.retrbinary(f"RETR {fileName}", file.write)
ftp.quit()


# with open(fileName, "r") as dataFile:
#     one = dataFile.readline()
#     print(one)
#     two = dataFile.readline()
#     print(two)

# can I just use read_csv and pandas to immediately read it into a Dataframe instead of using with open??? 
    # yes :) 
ACY = pd.read_csv(fileName, delimiter = "\t")
ACY.head()
# Out:
# curr diectory:
# -rw-rw-r--    1 1200     1200      3859444 Aug 16  2023 ACY738_ALL.txt
# -rw-rw-r--    1 1200     1200       719933 Aug 16  2023 ACY738_down, low confidence.txt
# -rw-rw-r--    1 1200     1200       123804 Aug 16  2023 ACY738_down.txt
# -rw-rw-r--    1 1200     1200      1923069 Aug 16  2023 ACY738_non-regulated.txt
# -rw-rw-r--    1 1200     1200       153580 Aug 16  2023 ACY738_up, low confidence.txt
# -rw-rw-r--    1 1200     1200        16422 Aug 16  2023 ACY738_up.txt
#           .pred_class     identifier    drug    gene     slope    bottom  \
# 0                  up  ACY738:Q9NVV5  ACY738  Q9NVV5 -5.324944  0.250050
# 1       non-regulated  ACY738:Q9Y365  ACY738  Q9Y365 -3.775753  0.250041
# 2  up, low confidence  ACY738:Q3T8J9  ACY738  Q3T8J9 -5.231305  0.564669
# 3       non-regulated  ACY738:Q9HCE7  ACY738  Q9HCE7  0.000400 -1.000930
# 4       non-regulated  ACY738:Q92539  ACY738  Q92539  0.000660 -1.003960
#
# ...

# %%
# combining for just 2 drugs (SIRT inhibitors)

selis = pd.read_csv("Selisistat_ALL.txt", delimiter = "\t")
srt = pd.read_csv("SRT2104_ALL.txt", delimiter = "\t")

#rename IC50 column to be the name of the drug
selisRenamed = selis[["gene", "stdIC50", "Mean_Intensity"]].rename(columns={"stdIC50": "Selisistat_IC50", "Mean_Intensity" : "Selisistat_Intensity"})
srtRenamed = srt[["gene", "stdIC50", "Mean_Intensity"]].rename(columns={"stdIC50": "SRT2104_IC50", "Mean_Intensity" : "SRT2104_Intensity"})

# merge the 2 IC50 columns on the "gene" column
combined = pd.merge(selisRenamed, srtRenamed, on="gene", how="outer")

#set gene as index
combined = combined.set_index("gene")

combined.head()

# %%
# practicing with FTP - moving back in directories so I can put the login stuff outside of a for loop 

from ftplib import FTP
# set up FTP 
ftp = FTP("massive-ftp.ucsd.edu")
ftp.login()

print("current (original) directory: ", ftp.pwd())

ftp.cwd("/v06/MSV000093659/other/Dose response data - Jurkat proteome")
print("current (jurkat proteome) directory: ", ftp.pwd())

drug = "Selisistat"
drugPath = f"{drug}/TXTs_Classified"
ftp.cwd(drugPath)
print("current (selisistat) directory: ", ftp.pwd())

ftp.cwd("../../")
print("current (one back?) directory", ftp.pwd()) # should be the same as (jurkat proteome) !!


ftp.quit()
# Out:
# current (original) directory:  /
# current (jurkat proteome) directory:  /v06/MSV000093659/other/Dose response data - Jurkat proteome
# current (selisistat) directory:  /v06/MSV000093659/other/Dose response data - Jurkat proteome/Selisistat/TXTs_Classified
# current (one back?) directory /v06/MSV000093659/other/Dose response data - Jurkat proteome
# '221 Goodbye.'
